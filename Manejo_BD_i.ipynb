# %% [markdown]
# <a href="https://colab.research.google.com/github/AleMarocho/Prueba/blob/main/Manejo_BD_i.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Manejo de bases de datos para las ciencias sociales I
#
# - [Introdución](#intro)
#     - [Importar pandas](#impa)
#     - [El Objeto DataFrame](#objdf)
# - [Creando Dataframes](#crea)
# - [Leyendo Dataframes](#readi)
# - [Desafíos comunes con archivos de datos](#desafio)
# - [Trabajando con datos](#trabajando)
#     - [Exploración inicial](#exploracion)
#     - [Cómo seleccionar datos](#select)
#     - [Filtrando información](#filter)

# %% [markdown]
# <a class="anchor" id="intro"></a>
# ## Introducción
#
# _Previo: Tipos de datos._
#
# Al 2025, Python tiene una serie de librerías que manejan bases de datos tabulares <sup>1</sup>.
#
# [Pandas](https://pandas.pydata.org/docs/getting_started/index.html) es la librería más popular de Python para realizar análisis de datos. Esta se especializa en trabajar con ciertos tipos de datos. Los más importantes son:
#
# - Data tabular, como los dataframes (o cualquier base de datos estructurada que tengamos).
# - Series
# - Series de tiempo
#
# Los objetos de Pandas más importantes son 2:
# - Series
# - Dataframes (nuestro enfoque principal).
#
# <sup>1</sup> Recientemente, la discusión ha virado a mejores métodos para tratar big data. Paquetes como dask, y tipos de archivos binarios como parquet, son un punto inicial. Lo importante es lo siguiente: Son extensiones de Pandas! :)

# %% [markdown]
# Esta librería es un _must_ en el aprendizaje del análisis de datos, machine learning, etc por una serie de motivos:
# - Se integra perfectamente con librerías como scikit-learn (machine learning), matplotlib, seaborn y altair (visualización de datos), statsmodels (modelos estadísticos listos para usar), análisis de texto, análisis espacial (geopandas, etc).
#
# - La gran parte de la comunidad que hace data analysis, y que se apoya mediante foros y demás, usa Pandas.
# - Pandas es muy amplio y tiene muchas funcionalidades.

# %% [markdown]
# <a class="anchor" id="impa"></a>
#
# ### 1. Importar pandas

# %%
import pandas as pd

# %% [markdown]
# <a class="anchor" id="objdf"></a>
#
# ### 2. El objeto dataframe
#
# - Casi siempre trabajaremos con dataframes.
#
# Pero qué es un dataframe?
#
#
# - Es el **objeto** principal de pandas, el cual representa una estructura de datos de dos dimensiones: filas y columnas.
# - Cada fila es una observación o registro;  cada columna, una variable, atributo, _feature_, etc.
# - Hay un sólo valor por celda.
# - El dataframe sirve para representar datos tabulares.
#
#
# Adicionalmente, todo dataframe tiene un **índice**, que funge como identificador único de cada fila.
# Las columnas no necesitan ello, porque por regla, los nombres ya son su identificador único. Por ello, no se acepta nombres repetidos de columna.
#
# 2 maneras de usar dataframes: crearlo por nosotros mismos ó leer datos.

# %% [markdown]
# <img src="../img/db_example.jpeg" width="800">
#
#
#
# <br>
# </br>

# %% [markdown]
# <a class="anchor" id="crea"></a>
#
# ####  Una forma simple de crear dataframes:

# %% [markdown]
# - Por filas

# %%
nombres_columnas = ['rural', 'pobreza', 'num_ccpp_urbano',
                    'desnutricion_cronica',
                    'centros_rural', 'es_juntos']

obs1 = [True, 40, 1, 50, 60, True]
obs2 = [True, 55, 2, 30, 55, True]
obs3 = [False, 25, 3, 40, 40, True]

obs4 = [True, 30, 2, 25, 55, False]

data = [obs1, obs2, obs3, obs4]

#ejemplo_df = pd.DataFrame(data = data, columns = nombres_columnas)

ejemplo_df  = pd.DataFrame(data = data, columns = nombres_columnas)


ejemplo_df
# Out:
#    rural  pobreza  num_ccpp_urbano  desnutricion_cronica  centros_rural  \
# 0   True       40                1                    50             60
# 1   True       55                2                    30             55
# 2  False       25                3                    40             40
# 3   True       30                2                    25             55
#
#    es_juntos
# 0       True
# 1       True
# 2       True
# 3      False

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# - Por columnas

# %%
# Ejemplo cuna más de anterior clase
df = pd.DataFrame()

df['rural'] = [True, True, False, True, False]
df['pobreza'] = [40, 55, 25, 60, 30]
df['rnum_ccpp_urbano'] =[1,2,3,4,5]
df['rdesnutricion_cronica'] = [50,30,40,20,45]
df['rcentros_rural'] = [60,55,40,50,20]
df['res_juntos'] = [True, True, True, True, True]


## df['cuna_o_no'] = [False, True, True, False, True]
df
# Out:
#    rural  pobreza  rnum_ccpp_urbano  rdesnutricion_cronica  rcentros_rural  \
# 0   True       40                 1                     50              60
# 1   True       55                 2                     30              55
# 2  False       25                 3                     40              40
# 3   True       60                 4                     20              50
# 4  False       30                 5                     45              20
#
#    res_juntos
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
type(pd.DataFrame())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Vectorización:
# La vectorización se define como aplicar una operación sobre el conjunto de elementos de un vector, en lugar de hacerlo sobre cada elemento de forma individual.
# Pandas integra dicha vectorización tal que las operaciones se realizan más rápida, fácil y eficientemente.

# %%
mivar = 5

# %%
# Ejemplo de vectorización:
## Nótese: Aquí creamos un dataframe con un diccionario, donde las llaves son los nombres de las columnas y
#  los valores son listas con los valores de cada columna.
df = pd.DataFrame({'vec': [1, 2, 3, 4, 5],
                   'non_vec': [1, 2, 3, 4, 5]})

# # No vectorizado: Se utiliza un bucle para realizar la operación.
for i in range(len(df)):
    df.at[i, 'non_vec'] += 10

# print(df)
# # Vewctorizado: Se llama al nombre de la variable como si fuera un vector.
df['vec'] = df['vec'] + 10

df
# Out:
#    vec  non_vec
# 0   11       11
# 1   12       12
# 2   13       13
# 3   14       14
# 4   15       15

# %%
df = pd.DataFrame({'vec': [1, 2, 3, 4, 5],
                   'non_vec': [1, 2, 3, 4, 5]})

len(df)
# Out:
# 5

# %%
df.at[0,"non_vec"]
# Out:
# np.int64(1)

# %%
for i in range(len(df)):
  df.at[i, "non_vec"]

# %%
df["vec"] += 10

# %% [markdown]
# <a class="anchor" id="readi"></a>
#
# #### Leyendo la información:
# Los archivos que tenemos pueden estar en distintos formatos: dta, sav, json, csv, txt. Pandas puede leer cualquiera de dichos tipos de archivos.
# Lo importante es que en esencia, todos ellos representan datos **tabulares**, o datos que tienen
#
#
# | Método de pandas según file | Tipo de archivo        | Descripción                              |
# |------------------|------------------------|------------------------------------------|
# | `read_csv()`     | CSV                    | Lee archivos de valores separados por comas (CSV). |
# | `read_json()`    | JSON                   | Lee datos estructurados como JSON. |
# | `read_stata()`   | Stata                  | Lee archivos de datos en Stata.          |
# | `read_spss()`    | SPSS                   | Lee archivos de datos en SPSS.           |
# | `read_excel()`   | Excel (xls, xlsx)      | Lee archivos Excel.              |
# | `read_pickle()`  | Pickle                 | Lee objetos Python serializados almacenados en archivos Pickle. |
# | `read_parquet()` | Parquet                | Lee archivos Parquet.         |
# | `read_feather()` | Feather                | Lee archivos Feather.         |
# | `read_sql()`     | SQL Query / Database   | Lee de una base de datos usando una consulta SQL. |
# | `read_sas()`     | SAS                    | Lee archivos de datos de SAS.            |
# | `read_hdf()`     | HDF5                   | Lee archivos HDF5.            |
# | `read_orc()`     | ORC                    | Lee archivos ORC.             |
# | `read_fwf()`     | Fixed-Width Formatted  | Lee archivos de texto con ancho fijo.    |
#
# - Los métodos están organizados según importancia.
# - Hay otros métodos como `read_html`, `read_orc`, y `read_fwf`. Otros paquetes adicionales leen, por ejemplo, archivos .RData (R).

# %% [markdown]
# Hoy nos enfocaremos en la base de datos de postulantes de la Universidad Nacional de Ingeniería:
# https://www.datosabiertos.gob.pe/dataset/postulantes-al-concurso-de-admisi%C3%B3n-de-la-universidad-nacional-de-ingenier%C3%ADa-uni

# %%
## Leyendo los archivos.
locacion_datos = "/Users/Lenovo/Downloads/Datos_abiertos_admision_2024_2_2025_1_0.csv"
df = pd.read_csv(locacion_datos)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1688006565.py in <cell line: 0>()
#       1 ## Leyendo los archivos.
#       2 locacion_datos = "/Users/Lenovo/Downloads/Datos_abiertos_admision_2024_2_2025_1_0.csv"
# ----> 3 df = pd.read_csv(locacion_datos)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/Lenovo/Downloads/Datos_abiertos_admision_2024_2_2025_1_0.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
locacion_datos = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQmJzJVRzCty6ohJIB28V3YpPnCjnOxgvYAWV5jvUZ78o6nco1K81xs1ijXlpsdw1GVYxHlijBq9pcH/pub?output=csv"
df = pd.read_csv(locacion_datos)

# %%
df
# Out:
#                                                   IDHASH  \
# 0      FCE35CE48F105003AD25D7F42AED473CF15C9B0908246D...
# 1      95282C5990D24FDD3D89A3E9635709C0A25697799F65C5...
# 2      6B0941B84A667898E34B981F7CF89497F3897BA5B6BA24...
# 3      A1DC21280879F9C205F7C421B8152BE338225A3359D6BF...
# 4      EF4BC1BD9F868AAA10BAA5F7BEC08141B9C0D5F0BF3809...
# ...                                                  ...
# 15371  7A76871277BF7B50009F4B81FA156045AA677DC1F42AC5...
# 15372  B66283E6A854E54D4312BCEAFF77FA5BFEB1F0CD66D344...
# 15373  0E51C416C1698AA217D8F1F23014D89711142D0DCF2F4D...
# 15374  BE5CD944A10F2E7F44D7DA77527BD405513F729B205498...
# 15375  57E091594DAC88B02597F63AE7C6F8DCAC13CB74F57717...
#
#                            COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0               VIRGEN DEL ROSARIO         LIMA         LIMA
# 1        MONSEÑOR MARCOS LIBARDONI         LIMA         LIMA
# 2                  3721 SANTA ROSA         LIMA         LIMA
# 3                        ARGENTINA         LIMA         LIMA
# 4                       SAN CARLOS         LIMA         LIMA
# ...                            ...          ...          ...
# 15371        1070 MELITON CARVAJAL         LIMA         LIMA
# 15372                    EL AMAUTA         LIMA         LIMA
# 15373              MOISES ZEBALLOS       ANCASH       SIHUAS
# 15374            6082 LOS PROCERES         LIMA         LIMA
# 15375  3045 JOSE CARLOS MARIATEGUI         LIMA         LIMA
#
#                COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                PACHACAMAC         PERÚ                 2023
# 1               LA VICTORIA         PERÚ                 2023
# 2                     ANCON         PERÚ                 2021
# 3                      LIMA         PERÚ                 2021
# 4                     COMAS         PERÚ                 2020
# ...                     ...          ...                  ...
# 15371                 LINCE         PERÚ                 2022
# 15372                 COMAS         PERÚ                 2021
# 15373             CHINGALPO         PERÚ                 2022
# 15374     SANTIAGO DE SURCO         PERÚ                 2022
# 15375  SAN MARTIN DE PORRES         PERÚ                 2023
#
#                   ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0       INGENIERÍA ELECTRÓNICA          2024              2  ...
# 1          INGENIERÍA MECÁNICA          2024              2  ...
# 2         INGENIERÍA ECONÓMICA          2024              2  ...
# 3                 ARQUITECTURA          2024              2  ...
# 4                 ARQUITECTURA          2024              2  ...
# ...                        ...           ...            ...  ...
# 15371   INGENIERÍA ELECTRÓNICA          2025              1  ...
# 15372  INGENIERÍA PETROQUÍMICA          2025              1  ...
# 15373   INGENIERÍA ESTADÍSTICA          2025              1  ...
# 15374         INGENIERÍA CIVIL          2025              1  ...
# 15375   INGENIERÍA MECATRÓNICA          2025              1  ...
#
#       ANIO_NACIMIENTO NACIMIENTO_PAIS NACIMIENTO_DEPA  NACIMIENTO_PROV  \
# 0                2007            PERÚ            LIMA             LIMA
# 1                2006            PERÚ            LIMA             LIMA
# 2                2006            PERÚ            LIMA             LIMA
# 3                2005            PERÚ      LAMBAYEQUE         CHICLAYO
# 4                2004            PERÚ            LIMA             LIMA
# ...               ...             ...             ...              ...
# 15371            2005            PERÚ            LIMA             LIMA
# 15372            2005            PERÚ            LIMA             LIMA
# 15373            2006            PERÚ          ANCASH           SIHUAS
# 15374            2005            PERÚ            LIMA             LIMA
# 15375            2007            PERÚ           JUNIN            JAUJA
#
#          NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  MODALIDAD  \
# 0            EL AGUSTINO  MASCULINO      13.382      SI  ORDINARIO
# 1            LA VICTORIA  MASCULINO       6.700      NO  ORDINARIO
# 2          PUENTE PIEDRA   FEMENINO       7.871      NO  ORDINARIO
# 3                 PATAPO   FEMENINO      12.536      NO  ORDINARIO
# 4            LA VICTORIA  MASCULINO      12.763      NO  ORDINARIO
# ...                  ...        ...         ...     ...        ...
# 15371                ATE  MASCULINO       3.205      NO  ORDINARIO
# 15372      PUENTE PIEDRA  MASCULINO       7.103      NO  ORDINARIO
# 15373          CHINGALPO  MASCULINO       3.044      NO  ORDINARIO
# 15374  SANTIAGO DE SURCO  MASCULINO       5.592      NO  ORDINARIO
# 15375              MASMA  MASCULINO       6.667      NO  ORDINARIO
#
#        FECHA_CORTE
# 0         20250630
# 1         20250630
# 2         20250630
# 3         20250630
# 4         20250630
# ...            ...
# 15371     20250630
# 15372     20250630
# 15373     20250630
# 15374     20250630
# 15375     20250630
#
# [15376 rows x 23 columns]

# %%
df.shape
# Out:
# (15376, 23)

# %% [markdown]
# <a class="anchor" id="desafio"></a>
#
# ### Desafíos comunes con archivos de datos.
#
# Recibir datos de terceros va a ser muy habitual en la labor de data scientists. Algunas situaciones a tener en cuenta (para el futuro), en particular con exceles y csvs, son las siguientes:
#
# Con CSV:
# - Problemas con los delimitadores: Lo común es  que el delimitador sea la coma `,`, sin embargo,`|`,  `;` ó incluso `Tab` pueden aparecer, lo que  originará errores de lectura si no se especifica el delimitador correcto.
# - Comillas que no cierran: `"""  ""`.
# - Codificación diferente:
#     - Datos en español en una codificación anglosajona (e.g.) ocasionará caracteres extraños.
#     - Tipo de datos diferente (string en vez de numérico).
# - Datos faltantes: la falta de comas puede ocasionar errores en cargar los datos.
# - Saltos de línea no sistemáticos
#
# Con Excel:
# - Datos no tabulares: Exceles que no tienen datos tabulares pueden ocasionar errores de lectura.
# - Más de un valor por celda.
# - Fórmulas de excel.

# %% [markdown]
# <a class="anchor" id="trabajando"></a>
#
# ### Trabajando con datos

# %% [markdown]
# <a class="anchor" id="exploracion"></a>
#
#
# ### Exploración inicial
#
# Los siguientes son métodos/atributos de exploración que aplicamos sobre el dataframe mismo.
#
# | Método / Atributo         | Descripción                                                                                             |
# |-----------------|---------------------------------------------------------------------------------------------------------|
# | `head(n)`/`tail(n)` | Muestra las primeras/últimas n filas del DataFrame.
# | `describe()`    | Da estadísticas como el promedio, desviación estándar, mínimo y máximo de **columnas numéricas**. |
# | `info()`        | Nos ofrece información importante como los tipos de los atributos y sus valores nulos.     |
# | `dtypes`        | Da los tipos de datos del dataframe                                             |
# | `shape`         | Informa sobre la dimensión del dataframe en forma de tupla `(nfilas, ncolumnas)` |
# | `columns`         | Informa sobre el nombre de las columnas del dataframe. |

# %%
df.describe()
# Out:
#        COLEGIO_ANIO_EGRESO  ANIO_POSTULA  CICLO_POSTULA  ANIO_NACIMIENTO  \
# count         15376.000000  15376.000000   15376.000000     15376.000000
# mean           2022.437370   2024.667209       1.332791      2005.916688
# std               2.029341      0.471228       0.471228         2.024890
# min            1982.000000   2024.000000       1.000000      1965.000000
# 25%            2022.000000   2024.000000       1.000000      2005.000000
# 50%            2023.000000   2025.000000       1.000000      2006.000000
# 75%            2024.000000   2025.000000       2.000000      2007.000000
# max            2026.000000   2025.000000       2.000000      2011.000000
#
#         CALIF_FINAL  FECHA_CORTE
# count  15376.000000      15376.0
# mean       7.844124   20250630.0
# std        3.455506          0.0
# min        0.000000   20250630.0
# 25%        5.121500   20250630.0
# 50%        7.646000   20250630.0
# 75%       10.497250   20250630.0
# max       18.440000   20250630.0

# %%
#df.describe()
#df.info()
#df.head()
#df.tail(4)

#df.dtypes
#df.shape
#df.columnns

# %% [markdown]
# Ahora exploraremos una columna en particular. Aquí se utilizará la exploración para una columna determinada (luego veremos que estas son Series).
#
# | Método          | Descripción                                                                                       |
# |-----------------|---------------------------------------------------------------------------------------------------|
# | `unique()`      | Da los valores únicos de la serie.                                                          |
# | `nunique()`     | Cuenta cuántos elementos únicos hay en la serie.                                                 |
# | `sort_values()` | Ordena la serie.         |
# | `value_counts()`| Da distribución de frecuencias de cada valor único de la serie.                                             |
#
#
# Para datos numéricos:
# `sum()`, `mean()`,  `min()`, `max()`, `mode()`, `median()` ,  `std()`

# %% [markdown]
# Ejercicios:
# - Averigua cuáles son los 5 primeros departamentos en donde nacen los postulantes.
# - Cuenta cuántos hombres/mujeres postulan a la UNI.
# - Cuenta cuántos ingresan.
# Hint: value_counts()

# %%
df['INGRESO'].value_counts(normalize = True)
# Out:
# INGRESO
# NO    0.841506
# SI    0.158494
# Name: proportion, dtype: float64

# %% [markdown]
# <a class="anchor" id="select"></a>
#
# ### Cómo seleccionar datos
#
# A veces sólo necesitamos entender una parte de todos nuestros datos. Por ejemplo, queremos ver los datos de los partidos políticos:

# %%
# df['ANIO_NACIMIENTO'].unique()
# df['ANIO_NACIMIENTO'].nunique()
# df['NACIMIENTO_DEPA'].value_counts()
# df['NACIMIENTO_DEPA'].value_counts(normalize = True)

# %%
pd.crosstab(df["ESPECIALIDAD"],df["ANIO_NACIMIENTO"])
# Out:
# ANIO_NACIMIENTO                               1965  1974  1976  1978  1979  \
# ESPECIALIDAD
# ARQUITECTURA                                     0     0     0     0     0
# CIENCIA DE LA COMPUTACIÓN                        0     0     0     1     0
# FÍSICA                                           0     0     0     0     0
# INGENIERIA AEROESPACIAL                          0     0     0     0     0
# INGENIERÍA AMBIENTAL                             0     0     0     0     0
# INGENIERÍA CIVIL                                 1     0     0     0     1
# INGENIERÍA DE CIBERSEGURIDAD                     0     0     0     0     0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL     0     0     0     0     0
# INGENIERÍA DE MINAS                              0     0     0     0     0
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL             0     0     0     0     0
# INGENIERÍA DE SISTEMAS                           0     2     1     0     0
# INGENIERÍA DE SOFTWARE                           0     0     0     0     0
# INGENIERÍA DE TELECOMUNICACIONES                 0     0     0     0     0
# INGENIERÍA ECONÓMICA                             0     0     0     0     0
# INGENIERÍA ELECTRÓNICA                           0     0     0     2     0
# INGENIERÍA ELÉCTRICA                             0     0     0     0     0
# INGENIERÍA ESTADÍSTICA                           0     0     0     0     0
# INGENIERÍA FÍSICA                                0     0     0     0     0
# INGENIERÍA GEOLÓGICA                             0     0     0     0     0
# INGENIERÍA INDUSTRIAL                            0     0     0     0     0
# INGENIERÍA MECATRÓNICA                           0     0     0     0     0
# INGENIERÍA MECÁNICA                              0     0     0     0     0
# INGENIERÍA MECÁNICA-ELÉCTRICA                    0     0     0     0     0
# INGENIERÍA METALÚRGICA                           0     0     0     0     0
# INGENIERÍA NAVAL                                 0     0     0     0     0
# INGENIERÍA PETROQUÍMICA                          0     0     0     0     0
# INGENIERÍA QUÍMICA                               0     0     0     0     0
# INGENIERÍA SANITARIA                             0     0     0     0     1
# INGENIERÍA TEXTIL                                0     0     0     0     0
# MATEMÁTICA                                       0     0     0     0     0
# QUÍMICA                                          0     0     0     0     0
#
# ANIO_NACIMIENTO                               1981  1982  1984  1986  1987  \
# ESPECIALIDAD
# ARQUITECTURA                                     0     0     0     1     0
# CIENCIA DE LA COMPUTACIÓN                        0     1     0     0     0
# FÍSICA                                           0     0     0     0     0
# INGENIERIA AEROESPACIAL                          0     0     0     0     0
# INGENIERÍA AMBIENTAL                             0     0     0     0     0
# INGENIERÍA CIVIL                                 0     0     0     0     0
# INGENIERÍA DE CIBERSEGURIDAD                     0     0     0     0     0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL     0     0     0     0     0
# INGENIERÍA DE MINAS                              0     0     1     0     0
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL             0     0     2     0     0
# INGENIERÍA DE SISTEMAS                           0     0     0     0     0
# INGENIERÍA DE SOFTWARE                           0     0     0     0     0
# INGENIERÍA DE TELECOMUNICACIONES                 0     0     0     0     0
# INGENIERÍA ECONÓMICA                             0     0     0     0     0
# INGENIERÍA ELECTRÓNICA                           0     0     0     0     0
# INGENIERÍA ELÉCTRICA                             0     0     0     0     0
# INGENIERÍA ESTADÍSTICA                           0     0     0     0     0
# INGENIERÍA FÍSICA                                0     0     0     0     0
# INGENIERÍA GEOLÓGICA                             0     0     0     0     0
# INGENIERÍA INDUSTRIAL                            0     0     0     0     0
# INGENIERÍA MECATRÓNICA                           0     0     0     0     0
# INGENIERÍA MECÁNICA                              1     0     0     0     0
# INGENIERÍA MECÁNICA-ELÉCTRICA                    0     0     0     0     0
# INGENIERÍA METALÚRGICA                           0     0     1     0     0
# INGENIERÍA NAVAL                                 0     0     0     0     0
# INGENIERÍA PETROQUÍMICA                          0     0     0     0     0
# INGENIERÍA QUÍMICA                               0     0     0     0     0
# INGENIERÍA SANITARIA                             0     0     0     0     0
# INGENIERÍA TEXTIL                                0     0     0     0     0
# MATEMÁTICA                                       0     0     1     0     2
# QUÍMICA                                          0     0     0     0     0
#
# ANIO_NACIMIENTO                               ...  2002  2003  2004  2005  \
# ESPECIALIDAD                                  ...
# ARQUITECTURA                                  ...    19    66   109   254
# CIENCIA DE LA COMPUTACIÓN                     ...     5    12    32    53
# FÍSICA                                        ...     3     9    18    14
# INGENIERIA AEROESPACIAL                       ...     4    11    21    28
# INGENIERÍA AMBIENTAL                          ...    14    16    44    66
# INGENIERÍA CIVIL                              ...    32    80   119   218
# INGENIERÍA DE CIBERSEGURIDAD                  ...     8    16    30    59
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL  ...     1    10    12    14
# INGENIERÍA DE MINAS                           ...    27    29    53   125
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL          ...     2     6     3    10
# INGENIERÍA DE SISTEMAS                        ...    19    30   110   241
# INGENIERÍA DE SOFTWARE                        ...     8    16    36    97
# INGENIERÍA DE TELECOMUNICACIONES              ...     3     5    34    54
# INGENIERÍA ECONÓMICA                          ...    14    24    64   116
# INGENIERÍA ELECTRÓNICA                        ...    18    21    32    91
# INGENIERÍA ELÉCTRICA                          ...    15    15    16    60
# INGENIERÍA ESTADÍSTICA                        ...     7     7    28    53
# INGENIERÍA FÍSICA                             ...     2     2     5    16
# INGENIERÍA GEOLÓGICA                          ...     4     6    17    47
# INGENIERÍA INDUSTRIAL                         ...    15    40    78   131
# INGENIERÍA MECATRÓNICA                        ...    13    35    66   116
# INGENIERÍA MECÁNICA                           ...    11    18    39    83
# INGENIERÍA MECÁNICA-ELÉCTRICA                 ...     8     7    16    45
# INGENIERÍA METALÚRGICA                        ...     0     1     6    25
# INGENIERÍA NAVAL                              ...     1     4    18    19
# INGENIERÍA PETROQUÍMICA                       ...     3     6    10    39
# INGENIERÍA QUÍMICA                            ...     7    26    48   138
# INGENIERÍA SANITARIA                          ...     7     5    24    55
# INGENIERÍA TEXTIL                             ...     2     4     6    12
# MATEMÁTICA                                    ...     0     2     8    14
# QUÍMICA                                       ...     3     4     9    16
#
# ANIO_NACIMIENTO                               2006  2007  2008  2009  2010  \
# ESPECIALIDAD
# ARQUITECTURA                                   307   375   174     3     0
# CIENCIA DE LA COMPUTACIÓN                       72    44    35     0     0
# FÍSICA                                          25    60    20     0     0
# INGENIERIA AEROESPACIAL                         66    70    36     0     0
# INGENIERÍA AMBIENTAL                            86    90    39     0     1
# INGENIERÍA CIVIL                               511   807   336     5     1
# INGENIERÍA DE CIBERSEGURIDAD                   106   116    48     0     0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL    20    14     7     0     0
# INGENIERÍA DE MINAS                            180   213    90     0     1
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL            22    12     7     0     0
# INGENIERÍA DE SISTEMAS                         503   756   328     4     0
# INGENIERÍA DE SOFTWARE                         152   237    90     3     0
# INGENIERÍA DE TELECOMUNICACIONES                36    60    13     0     0
# INGENIERÍA ECONÓMICA                           176   188    85     0     0
# INGENIERÍA ELECTRÓNICA                         118   147    59     1     0
# INGENIERÍA ELÉCTRICA                            98   103    35     0     0
# INGENIERÍA ESTADÍSTICA                          73    55    17     0     0
# INGENIERÍA FÍSICA                               24    28     9     0     0
# INGENIERÍA GEOLÓGICA                            46    53    16     0     0
# INGENIERÍA INDUSTRIAL                          303   348   171     2     0
# INGENIERÍA MECATRÓNICA                         292   449   244     3     0
# INGENIERÍA MECÁNICA                            150   158    63     0     0
# INGENIERÍA MECÁNICA-ELÉCTRICA                   61    78    15     0     0
# INGENIERÍA METALÚRGICA                          35    32    10     0     0
# INGENIERÍA NAVAL                                32    39    18     1     0
# INGENIERÍA PETROQUÍMICA                         26    25    10     0     0
# INGENIERÍA QUÍMICA                             201   151    61     1     0
# INGENIERÍA SANITARIA                            55    32    18     0     0
# INGENIERÍA TEXTIL                                7    14     4     0     0
# MATEMÁTICA                                      31    44    10     1     0
# QUÍMICA                                         21    14     6     0     0
#
# ANIO_NACIMIENTO                               2011
# ESPECIALIDAD
# ARQUITECTURA                                     0
# CIENCIA DE LA COMPUTACIÓN                        0
# FÍSICA                                           0
# INGENIERIA AEROESPACIAL                          0
# INGENIERÍA AMBIENTAL                             0
# INGENIERÍA CIVIL                                 0
# INGENIERÍA DE CIBERSEGURIDAD                     0
# INGENIERÍA DE HIGIENE Y SEGURIDAD INDUSTRIAL     0
# INGENIERÍA DE MINAS                              0
# INGENIERÍA DE PETRÓLEO Y GAS NATURAL             0
# INGENIERÍA DE SISTEMAS                           0
# INGENIERÍA DE SOFTWARE                           0
# INGENIERÍA DE TELECOMUNICACIONES                 0
# INGENIERÍA ECONÓMICA                             0
# INGENIERÍA ELECTRÓNICA                           0
# INGENIERÍA ELÉCTRICA                             0
# INGENIERÍA ESTADÍSTICA                           0
# INGENIERÍA FÍSICA                                0
# INGENIERÍA GEOLÓGICA                             1
# INGENIERÍA INDUSTRIAL                            0
# INGENIERÍA MECATRÓNICA                           0
# INGENIERÍA MECÁNICA                              0
# INGENIERÍA MECÁNICA-ELÉCTRICA                    0
# INGENIERÍA METALÚRGICA                           0
# INGENIERÍA NAVAL                                 0
# INGENIERÍA PETROQUÍMICA                          0
# INGENIERÍA QUÍMICA                               0
# INGENIERÍA SANITARIA                             0
# INGENIERÍA TEXTIL                                0
# MATEMÁTICA                                       1
# QUÍMICA                                          0
#
# [31 rows x 33 columns]

# %% [markdown]
# Un dataframe está compuesto de varias series: una columna es una serie diferente.

# %%
type(df['ANIO_NACIMIENTO']) # Forma de acceder a una columna.
# Otra forma:
# df.ANIO_NACIMIENTO # Mejor utilizar la anterior!

# Acceder a varias columnas:
df[['ANIO_NACIMIENTO', 'NACIMIENTO_DEPA']]
# Out:
#        ANIO_NACIMIENTO NACIMIENTO_DEPA
# 0                 2007            LIMA
# 1                 2006            LIMA
# 2                 2006            LIMA
# 3                 2005      LAMBAYEQUE
# 4                 2004            LIMA
# ...                ...             ...
# 15371             2005            LIMA
# 15372             2005            LIMA
# 15373             2006          ANCASH
# 15374             2005            LIMA
# 15375             2007           JUNIN
#
# [15376 rows x 2 columns]

# %%
#### Explorando más de una columna:

# %%
pd.crosstab(df['NACIMIENTO_DEPA'], df['SEXO'])

# esta funcion nos permite hacer tablas cruzadas entre dos columnas.

pd.crosstab(df['NACIMIENTO_DEPA'], df['SEXO'])
# Out:
# SEXO             FEMENINO  MASCULINO
# NACIMIENTO_DEPA
# AMAZONAS               20         81
# ANCASH                 61        384
# APURIMAC               32        129
# AREQUIPA               23        101
# AYACUCHO               59        222
# CAJAMARCA              43        183
# CALLAO                227        636
# CUSCO                  36        145
# ESPANA                  1          0
# HUANCAVELICA           23        101
# HUANUCO                46        159
# ICA                    38        160
# JUNIN                 134        498
# LA LIBERTAD            26        100
# LAMBAYEQUE             38        171
# LIMA                 2539       8032
# LORETO                 17         48
# MADRE DE DIOS           3         11
# MOQUEGUA                2         26
# OTRO                    2         12
# PASCO                  21        108
# PIURA                  19         79
# PUNO                   61        307
# SAN MARTIN             10         73
# TACNA                  14         48
# TUMBES                  5         18
# UCAYALI                 6         35
# VENEZUELA               0          3

# %% [markdown]
# ### Selección de datos

# %% [markdown]
# #### Selección de columnas

# %%
# por nombre:
peque_lst = ['ANIO_NACIMIENTO', 'NACIMIENTO_DEPA']
#df[peque_lst]

# %%
df_small = df[peque_lst].copy()
df_small

# %% [markdown]
# #### Selección y filtración de filas/columnas con ``` iloc``` y ```loc ```
#
# Primero seleccionaremos columnas, para lo que utilizaremos  ``` iloc``` y ```loc ```.

# %% [markdown]
# ##### Utilizando el iloc
# El iloc ubica las observaciones que corresponden al índice que le indicamos.
# Recordando nuestra base de postulantes:

# %%
# Agarrando observaciones puntuales

df.iloc[[0,4,10]]
# Out:
#                                                IDHASH             COLEGIO  \
# 0   FCE35CE48F105003AD25D7F42AED473CF15C9B0908246D...  VIRGEN DEL ROSARIO
# 4   EF4BC1BD9F868AAA10BAA5F7BEC08141B9C0D5F0BF3809...          SAN CARLOS
# 10  EA5B4F9447C24AE57E2D77CA44E330444B33273616EA95...    2056 JOSE GALVEZ
#
#    COLEGIO_DEPA COLEGIO_PROV   COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0          LIMA         LIMA     PACHACAMAC         PERÚ                 2023
# 4          LIMA         LIMA          COMAS         PERÚ                 2020
# 10         LIMA         LIMA  INDEPENDENCIA         PERÚ                 2019
#
#               ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ... ANIO_NACIMIENTO  \
# 0   INGENIERÍA ELECTRÓNICA          2024              2  ...            2007
# 4             ARQUITECTURA          2024              2  ...            2004
# 10            ARQUITECTURA          2024              2  ...            2003
#
#    NACIMIENTO_PAIS NACIMIENTO_DEPA  NACIMIENTO_PROV NACIMIENTO_DIST  \
# 0             PERÚ            LIMA             LIMA     EL AGUSTINO
# 4             PERÚ            LIMA             LIMA     LA VICTORIA
# 10            PERÚ            LIMA             LIMA            LIMA
#
#          SEXO CALIF_FINAL INGRESO  MODALIDAD  FECHA_CORTE
# 0   MASCULINO      13.382      SI  ORDINARIO     20250630
# 4   MASCULINO      12.763      NO  ORDINARIO     20250630
# 10   FEMENINO       7.813      NO  ORDINARIO     20250630
#
# [3 rows x 23 columns]

# %%
cols = [0,4,10]
rows = [1,2]
df.iloc[rows,cols]
# Out:
#                                               IDHASH COLEGIO_DIST  \
# 1  95282C5990D24FDD3D89A3E9635709C0A25697799F65C5...  LA VICTORIA
# 2  6B0941B84A667898E34B981F7CF89497F3897BA5B6BA24...        ANCON
#
#   DOMICILIO_DEPA
# 1           LIMA
# 2           LIMA

# %%
#Buscar partes usando la posición de los índices y las columnas
df.iloc[4000 :, [3]]
# Out:
#       COLEGIO_PROV
# 4000          LIMA
# 4001        HUARAL
# 4002          LIMA
# 4003          LIMA
# 4004     CAJAMARCA
# ...            ...
# 15371         LIMA
# 15372         LIMA
# 15373       SIHUAS
# 15374         LIMA
# 15375         LIMA
#
# [11376 rows x 1 columns]

# %%
# Agarrando observaciones puntuales definidas por su indice
rows = [1, 2, 10,13,3000]
df.iloc[rows]
# Out:
#                                                  IDHASH  \
# 1     95282C5990D24FDD3D89A3E9635709C0A25697799F65C5...
# 2     6B0941B84A667898E34B981F7CF89497F3897BA5B6BA24...
# 10    EA5B4F9447C24AE57E2D77CA44E330444B33273616EA95...
# 13    9EC6DCBB0A822AB1043611705A4402F7BBD35E70DB8817...
# 3000  F63963087C7B3706A5AA84B82166D11B48B825FDBE9419...
#
#                         COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 1     MONSEÑOR MARCOS LIBARDONI         LIMA         LIMA
# 2               3721 SANTA ROSA         LIMA         LIMA
# 10             2056 JOSE GALVEZ         LIMA         LIMA
# 13         SACO OLIVEROS DE PRO         LIMA         LIMA
# 3000    3027 CORONEL JOSE BALTA         LIMA         LIMA
#
#               COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 1              LA VICTORIA         PERÚ                 2023
# 2                    ANCON         PERÚ                 2021
# 10           INDEPENDENCIA         PERÚ                 2019
# 13              LOS OLIVOS         PERÚ                 2023
# 3000  SAN MARTIN DE PORRES         PERÚ                 2022
#
#                 ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 1        INGENIERÍA MECÁNICA          2024              2  ...
# 2       INGENIERÍA ECONÓMICA          2024              2  ...
# 10              ARQUITECTURA          2024              2  ...
# 13          INGENIERÍA CIVIL          2024              2  ...
# 3000  INGENIERÍA DE SOFTWARE          2024              2  ...
#
#      ANIO_NACIMIENTO NACIMIENTO_PAIS NACIMIENTO_DEPA  NACIMIENTO_PROV  \
# 1               2006            PERÚ            LIMA             LIMA
# 2               2006            PERÚ            LIMA             LIMA
# 10              2003            PERÚ            LIMA             LIMA
# 13              2006            PERÚ            LIMA             LIMA
# 3000            2005            PERÚ            LIMA             LIMA
#
#      NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  MODALIDAD  FECHA_CORTE
# 1        LA VICTORIA  MASCULINO       6.700      NO  ORDINARIO     20250630
# 2      PUENTE PIEDRA   FEMENINO       7.871      NO  ORDINARIO     20250630
# 10              LIMA   FEMENINO       7.813      NO  ORDINARIO     20250630
# 13              LIMA  MASCULINO       4.018      NO  ORDINARIO     20250630
# 3000     JESUS MARIA  MASCULINO       4.833      NO  ORDINARIO     20250630
#
# [5 rows x 23 columns]

# %%
rows = [10,13, 2]
cols = [2,4,6]
df.iloc[rows, cols]
# Out:
#    COLEGIO_DEPA   COLEGIO_DIST  COLEGIO_ANIO_EGRESO
# 10         LIMA  INDEPENDENCIA                 2019
# 13         LIMA     LOS OLIVOS                 2023
# 2          LIMA          ANCON                 2021

# %%
df.iloc[3:, [4]]
# Out:
#                COLEGIO_DIST
# 3                      LIMA
# 4                     COMAS
# 5             SAN SEBASTIAN
# 6               SAN ANTONIO
# 7      SAN MARTIN DE PORRES
# ...                     ...
# 15371                 LINCE
# 15372                 COMAS
# 15373             CHINGALPO
# 15374     SANTIAGO DE SURCO
# 15375  SAN MARTIN DE PORRES
#
# [15373 rows x 1 columns]

# %%
# qué pasa si  hago...
#df.iloc[rows, ['COLEGIO_DEPA', 'COLEGIO_PROV', 'COLEGIO_ANIO_EGRESO']]

# %%
columnas = ['COLEGIO_DEPA', 'COLEGIO_PROV', 'COLEGIO_ANIO_EGRESO']
filas = range(0,6)
df.loc[filas, columnas]
# Out:
#   COLEGIO_DEPA COLEGIO_PROV  COLEGIO_ANIO_EGRESO
# 0         LIMA         LIMA                 2023
# 1         LIMA         LIMA                 2023
# 2         LIMA         LIMA                 2021
# 3         LIMA         LIMA                 2021
# 4         LIMA         LIMA                 2020
# 5        CUSCO        CUSCO                 2023

# %%
#INDICE PARA LOS NOMBRES
df2 = df.set_index("IDHASH")

# %%
df.iloc[:3,:3]

# %% [markdown]
# ##### Utilizando el ```loc```
#
# El ``` loc``` es una forma de ubicar observaciones que se basa en las etiquetas, tanto de columnas como de filas.

# %%
columnas = ['COLEGIO_DEPA', 'COLEGIO_PROV', 'COLEGIO_ANIO_EGRESO']
filas = range(0,6)
df.loc[filas, columnas]

# %%
df2 = df.set_index('IDHASH') ## funciones HASH

# %%
df2.loc['E4287C2FE19F63C5E6641955147E36684A5A2FF8064676B6CB00A57522FD99A8175BC39CB2924C9F4D3848443267048FE4CB946A191592F9053A3D1705456A26']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'E4287C2FE19F63C5E6641955147E36684A5A2FF8064676B6CB00A57522FD99A8175BC39CB2924C9F4D3848443267048FE4CB946A191592F9053A3D1705456A26'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1273883407.py in <cell line: 0>()
# ----> 1 df2.loc['E4287C2FE19F63C5E6641955147E36684A5A2FF8064676B6CB00A57522FD99A8175BC39CB2924C9F4D3848443267048FE4CB946A191592F9053A3D1705456A26']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1429         # fall thru to straight lookup
#    1430         self._validate_key(key, axis)
# -> 1431         return self._get_label(key, axis=axis)
#    1432
#    1433     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1379     def _get_label(self, label, axis: AxisInt):
#    1380         # GH#5567 this will fail if the label is not present in the axis.
# -> 1381         return self.obj.xs(label, axis=axis)
#    1382
#    1383     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4299                     new_index = index[loc]
#    4300         else:
# -> 4301             loc = index.get_loc(key)
#    4302
#    4303             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'E4287C2FE19F63C5E6641955147E36684A5A2FF8064676B6CB00A57522FD99A8175BC39CB2924C9F4D3848443267048FE4CB946A191592F9053A3D1705456A26'

# %%
df.loc[:, columnas]

#  Con .iloc y .loc, hemos visto nuevas formas de acceder a las filas/columnas de un dataframe:
# df.loc[:, ['ANIO_NACIMIENTO', 'NACIMIENTO_DEPA']]
# df.loc[1:3, ['ANIO_NACIMIENTO', 'NACIMIENTO_DEPA']]
# df.iloc[:, [1, 2]]
# df.iloc[1:3, 2:4]
# Out:
#       COLEGIO_DEPA COLEGIO_PROV  COLEGIO_ANIO_EGRESO
# 0             LIMA         LIMA                 2023
# 1             LIMA         LIMA                 2023
# 2             LIMA         LIMA                 2021
# 3             LIMA         LIMA                 2021
# 4             LIMA         LIMA                 2020
# ...            ...          ...                  ...
# 15371         LIMA         LIMA                 2022
# 15372         LIMA         LIMA                 2021
# 15373       ANCASH       SIHUAS                 2022
# 15374         LIMA         LIMA                 2022
# 15375         LIMA         LIMA                 2023
#
# [15376 rows x 3 columns]

# %% [markdown]
# <a class="anchor" id="filter"></a>
#
# ### Filtrando información
#
# Muchas veces querremos quedarnos con un subconjunto de datos que cumplen cierta condición. Las condiciones tienen que evaluarse a un booleano.

# %%
df[df["NACIMIENTO_PAIS"] == "PERÚ"]
# Out:
#                                                   IDHASH  \
# 0      FCE35CE48F105003AD25D7F42AED473CF15C9B0908246D...
# 1      95282C5990D24FDD3D89A3E9635709C0A25697799F65C5...
# 2      6B0941B84A667898E34B981F7CF89497F3897BA5B6BA24...
# 3      A1DC21280879F9C205F7C421B8152BE338225A3359D6BF...
# 4      EF4BC1BD9F868AAA10BAA5F7BEC08141B9C0D5F0BF3809...
# ...                                                  ...
# 15371  7A76871277BF7B50009F4B81FA156045AA677DC1F42AC5...
# 15372  B66283E6A854E54D4312BCEAFF77FA5BFEB1F0CD66D344...
# 15373  0E51C416C1698AA217D8F1F23014D89711142D0DCF2F4D...
# 15374  BE5CD944A10F2E7F44D7DA77527BD405513F729B205498...
# 15375  57E091594DAC88B02597F63AE7C6F8DCAC13CB74F57717...
#
#                            COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0               VIRGEN DEL ROSARIO         LIMA         LIMA
# 1        MONSEÑOR MARCOS LIBARDONI         LIMA         LIMA
# 2                  3721 SANTA ROSA         LIMA         LIMA
# 3                        ARGENTINA         LIMA         LIMA
# 4                       SAN CARLOS         LIMA         LIMA
# ...                            ...          ...          ...
# 15371        1070 MELITON CARVAJAL         LIMA         LIMA
# 15372                    EL AMAUTA         LIMA         LIMA
# 15373              MOISES ZEBALLOS       ANCASH       SIHUAS
# 15374            6082 LOS PROCERES         LIMA         LIMA
# 15375  3045 JOSE CARLOS MARIATEGUI         LIMA         LIMA
#
#                COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                PACHACAMAC         PERÚ                 2023
# 1               LA VICTORIA         PERÚ                 2023
# 2                     ANCON         PERÚ                 2021
# 3                      LIMA         PERÚ                 2021
# 4                     COMAS         PERÚ                 2020
# ...                     ...          ...                  ...
# 15371                 LINCE         PERÚ                 2022
# 15372                 COMAS         PERÚ                 2021
# 15373             CHINGALPO         PERÚ                 2022
# 15374     SANTIAGO DE SURCO         PERÚ                 2022
# 15375  SAN MARTIN DE PORRES         PERÚ                 2023
#
#                   ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0       INGENIERÍA ELECTRÓNICA          2024              2  ...
# 1          INGENIERÍA MECÁNICA          2024              2  ...
# 2         INGENIERÍA ECONÓMICA          2024              2  ...
# 3                 ARQUITECTURA          2024              2  ...
# 4                 ARQUITECTURA          2024              2  ...
# ...                        ...           ...            ...  ...
# 15371   INGENIERÍA ELECTRÓNICA          2025              1  ...
# 15372  INGENIERÍA PETROQUÍMICA          2025              1  ...
# 15373   INGENIERÍA ESTADÍSTICA          2025              1  ...
# 15374         INGENIERÍA CIVIL          2025              1  ...
# 15375   INGENIERÍA MECATRÓNICA          2025              1  ...
#
#       ANIO_NACIMIENTO NACIMIENTO_PAIS NACIMIENTO_DEPA  NACIMIENTO_PROV  \
# 0                2007            PERÚ            LIMA             LIMA
# 1                2006            PERÚ            LIMA             LIMA
# 2                2006            PERÚ            LIMA             LIMA
# 3                2005            PERÚ      LAMBAYEQUE         CHICLAYO
# 4                2004            PERÚ            LIMA             LIMA
# ...               ...             ...             ...              ...
# 15371            2005            PERÚ            LIMA             LIMA
# 15372            2005            PERÚ            LIMA             LIMA
# 15373            2006            PERÚ          ANCASH           SIHUAS
# 15374            2005            PERÚ            LIMA             LIMA
# 15375            2007            PERÚ           JUNIN            JAUJA
#
#          NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  MODALIDAD  \
# 0            EL AGUSTINO  MASCULINO      13.382      SI  ORDINARIO
# 1            LA VICTORIA  MASCULINO       6.700      NO  ORDINARIO
# 2          PUENTE PIEDRA   FEMENINO       7.871      NO  ORDINARIO
# 3                 PATAPO   FEMENINO      12.536      NO  ORDINARIO
# 4            LA VICTORIA  MASCULINO      12.763      NO  ORDINARIO
# ...                  ...        ...         ...     ...        ...
# 15371                ATE  MASCULINO       3.205      NO  ORDINARIO
# 15372      PUENTE PIEDRA  MASCULINO       7.103      NO  ORDINARIO
# 15373          CHINGALPO  MASCULINO       3.044      NO  ORDINARIO
# 15374  SANTIAGO DE SURCO  MASCULINO       5.592      NO  ORDINARIO
# 15375              MASMA  MASCULINO       6.667      NO  ORDINARIO
#
#        FECHA_CORTE
# 0         20250630
# 1         20250630
# 2         20250630
# 3         20250630
# 4         20250630
# ...            ...
# 15371     20250630
# 15372     20250630
# 15373     20250630
# 15374     20250630
# 15375     20250630
#
# [15374 rows x 23 columns]

# %%
cond_1 = df["COLEGIO_DEPA"] == "LIMA"
cond_2 = df["INGRESO"] == "NO"

df[cond_1 | cond_2]
# Out:
#                                                   IDHASH  \
# 0      FCE35CE48F105003AD25D7F42AED473CF15C9B0908246D...
# 1      95282C5990D24FDD3D89A3E9635709C0A25697799F65C5...
# 2      6B0941B84A667898E34B981F7CF89497F3897BA5B6BA24...
# 3      A1DC21280879F9C205F7C421B8152BE338225A3359D6BF...
# 4      EF4BC1BD9F868AAA10BAA5F7BEC08141B9C0D5F0BF3809...
# ...                                                  ...
# 15371  7A76871277BF7B50009F4B81FA156045AA677DC1F42AC5...
# 15372  B66283E6A854E54D4312BCEAFF77FA5BFEB1F0CD66D344...
# 15373  0E51C416C1698AA217D8F1F23014D89711142D0DCF2F4D...
# 15374  BE5CD944A10F2E7F44D7DA77527BD405513F729B205498...
# 15375  57E091594DAC88B02597F63AE7C6F8DCAC13CB74F57717...
#
#                            COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0               VIRGEN DEL ROSARIO         LIMA         LIMA
# 1        MONSEÑOR MARCOS LIBARDONI         LIMA         LIMA
# 2                  3721 SANTA ROSA         LIMA         LIMA
# 3                        ARGENTINA         LIMA         LIMA
# 4                       SAN CARLOS         LIMA         LIMA
# ...                            ...          ...          ...
# 15371        1070 MELITON CARVAJAL         LIMA         LIMA
# 15372                    EL AMAUTA         LIMA         LIMA
# 15373              MOISES ZEBALLOS       ANCASH       SIHUAS
# 15374            6082 LOS PROCERES         LIMA         LIMA
# 15375  3045 JOSE CARLOS MARIATEGUI         LIMA         LIMA
#
#                COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                PACHACAMAC         PERÚ                 2023
# 1               LA VICTORIA         PERÚ                 2023
# 2                     ANCON         PERÚ                 2021
# 3                      LIMA         PERÚ                 2021
# 4                     COMAS         PERÚ                 2020
# ...                     ...          ...                  ...
# 15371                 LINCE         PERÚ                 2022
# 15372                 COMAS         PERÚ                 2021
# 15373             CHINGALPO         PERÚ                 2022
# 15374     SANTIAGO DE SURCO         PERÚ                 2022
# 15375  SAN MARTIN DE PORRES         PERÚ                 2023
#
#                   ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0       INGENIERÍA ELECTRÓNICA          2024              2  ...
# 1          INGENIERÍA MECÁNICA          2024              2  ...
# 2         INGENIERÍA ECONÓMICA          2024              2  ...
# 3                 ARQUITECTURA          2024              2  ...
# 4                 ARQUITECTURA          2024              2  ...
# ...                        ...           ...            ...  ...
# 15371   INGENIERÍA ELECTRÓNICA          2025              1  ...
# 15372  INGENIERÍA PETROQUÍMICA          2025              1  ...
# 15373   INGENIERÍA ESTADÍSTICA          2025              1  ...
# 15374         INGENIERÍA CIVIL          2025              1  ...
# 15375   INGENIERÍA MECATRÓNICA          2025              1  ...
#
#       ANIO_NACIMIENTO NACIMIENTO_PAIS NACIMIENTO_DEPA  NACIMIENTO_PROV  \
# 0                2007            PERÚ            LIMA             LIMA
# 1                2006            PERÚ            LIMA             LIMA
# 2                2006            PERÚ            LIMA             LIMA
# 3                2005            PERÚ      LAMBAYEQUE         CHICLAYO
# 4                2004            PERÚ            LIMA             LIMA
# ...               ...             ...             ...              ...
# 15371            2005            PERÚ            LIMA             LIMA
# 15372            2005            PERÚ            LIMA             LIMA
# 15373            2006            PERÚ          ANCASH           SIHUAS
# 15374            2005            PERÚ            LIMA             LIMA
# 15375            2007            PERÚ           JUNIN            JAUJA
#
#          NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  MODALIDAD  \
# 0            EL AGUSTINO  MASCULINO      13.382      SI  ORDINARIO
# 1            LA VICTORIA  MASCULINO       6.700      NO  ORDINARIO
# 2          PUENTE PIEDRA   FEMENINO       7.871      NO  ORDINARIO
# 3                 PATAPO   FEMENINO      12.536      NO  ORDINARIO
# 4            LA VICTORIA  MASCULINO      12.763      NO  ORDINARIO
# ...                  ...        ...         ...     ...        ...
# 15371                ATE  MASCULINO       3.205      NO  ORDINARIO
# 15372      PUENTE PIEDRA  MASCULINO       7.103      NO  ORDINARIO
# 15373          CHINGALPO  MASCULINO       3.044      NO  ORDINARIO
# 15374  SANTIAGO DE SURCO  MASCULINO       5.592      NO  ORDINARIO
# 15375              MASMA  MASCULINO       6.667      NO  ORDINARIO
#
#        FECHA_CORTE
# 0         20250630
# 1         20250630
# 2         20250630
# 3         20250630
# 4         20250630
# ...            ...
# 15371     20250630
# 15372     20250630
# 15373     20250630
# 15374     20250630
# 15375     20250630
#
# [14806 rows x 23 columns]

# %% [markdown]
# #### Filtrando información con condiciones

# %%
# Podemos guardar las condiciones como variables y luego hacer el filtro.

condicion = [True]*(len(df) - 5) + [False] * (5) # Tenemos una lista de booleanons de la longitud del dataframe.
#df[condicion] # Filtramos el dataframe con la condición.

condicion

# %%
cond = df['COLEGIO_DEPA'] == 'LIMA'
# explora qué bota el cond.

df[cond]
df[cond].reset_index(drop = True) # drop = True sirve para q no se quede ennuewtro  dataframe

# %%
cond_1 = df['COLEGIO_DEPA'] == "LIMA"
cond_2 = df['INGRESO'] == "NO"

cond_filtrado_and = df[cond_1 & cond_2] ## Pregunta: por qué no usamos el and y or, como habíamos visto antes?

cond_filtrado_or = df[cond_1 | cond_2]

## equivalente a:
df[(
    df['COLEGIO_DEPA'] == "LIMA"
) & (
    df['INGRESO'] == "NO"
    )] ## necesitamos cerrarlo en paréntesis.

df[(df['COLEGIO_DEPA'] == "LIMA") | (df['INGRESO'] == "NO")]

# Nota1: Si queremos hacer un filtro con más de una condición, necesitamos cerrar cada condición en paréntesis.
# Nota2: Podemos almacenar el resultado como una variable, que será un dataframe nuevo.

# %%
cond_1 = df['COLEGIO_DEPA'] == "LIMA"
cond_2 = df['INGRESO'] == "NO"

cond_filtrado_and = df[cond_1 & cond_2]

cond_filtrado_and

# %%
## Ejercicio: Filtra el dataframe para que solo te quedes con las observaciones que sean de Lima y que hayan ingresado.

# %%
#df.query('ANIO_POSTULA > 2020')

# %%
df[df['COLEGIO_DEPA'].isin(['LIMA', 'CALLAO'])]
# Out:
#                                                   IDHASH  \
# 0      FCE35CE48F105003AD25D7F42AED473CF15C9B0908246D...
# 1      95282C5990D24FDD3D89A3E9635709C0A25697799F65C5...
# 2      6B0941B84A667898E34B981F7CF89497F3897BA5B6BA24...
# 3      A1DC21280879F9C205F7C421B8152BE338225A3359D6BF...
# 4      EF4BC1BD9F868AAA10BAA5F7BEC08141B9C0D5F0BF3809...
# ...                                                  ...
# 15369  F59425979C700280AA8141EC03A923C8D7E89CC16C1C2D...
# 15371  7A76871277BF7B50009F4B81FA156045AA677DC1F42AC5...
# 15372  B66283E6A854E54D4312BCEAFF77FA5BFEB1F0CD66D344...
# 15374  BE5CD944A10F2E7F44D7DA77527BD405513F729B205498...
# 15375  57E091594DAC88B02597F63AE7C6F8DCAC13CB74F57717...
#
#                            COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0               VIRGEN DEL ROSARIO         LIMA         LIMA
# 1        MONSEÑOR MARCOS LIBARDONI         LIMA         LIMA
# 2                  3721 SANTA ROSA         LIMA         LIMA
# 3                        ARGENTINA         LIMA         LIMA
# 4                       SAN CARLOS         LIMA         LIMA
# ...                            ...          ...          ...
# 15369         REPUBLICA DE BOLIVIA         LIMA         LIMA
# 15371        1070 MELITON CARVAJAL         LIMA         LIMA
# 15372                    EL AMAUTA         LIMA         LIMA
# 15374            6082 LOS PROCERES         LIMA         LIMA
# 15375  3045 JOSE CARLOS MARIATEGUI         LIMA         LIMA
#
#                COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                PACHACAMAC         PERÚ                 2023
# 1               LA VICTORIA         PERÚ                 2023
# 2                     ANCON         PERÚ                 2021
# 3                      LIMA         PERÚ                 2021
# 4                     COMAS         PERÚ                 2020
# ...                     ...          ...                  ...
# 15369     VILLA EL SALVADOR         PERÚ                 2023
# 15371                 LINCE         PERÚ                 2022
# 15372                 COMAS         PERÚ                 2021
# 15374     SANTIAGO DE SURCO         PERÚ                 2022
# 15375  SAN MARTIN DE PORRES         PERÚ                 2023
#
#                   ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0       INGENIERÍA ELECTRÓNICA          2024              2  ...
# 1          INGENIERÍA MECÁNICA          2024              2  ...
# 2         INGENIERÍA ECONÓMICA          2024              2  ...
# 3                 ARQUITECTURA          2024              2  ...
# 4                 ARQUITECTURA          2024              2  ...
# ...                        ...           ...            ...  ...
# 15369     INGENIERÍA ELÉCTRICA          2025              1  ...
# 15371   INGENIERÍA ELECTRÓNICA          2025              1  ...
# 15372  INGENIERÍA PETROQUÍMICA          2025              1  ...
# 15374         INGENIERÍA CIVIL          2025              1  ...
# 15375   INGENIERÍA MECATRÓNICA          2025              1  ...
#
#       ANIO_NACIMIENTO NACIMIENTO_PAIS NACIMIENTO_DEPA  NACIMIENTO_PROV  \
# 0                2007            PERÚ            LIMA             LIMA
# 1                2006            PERÚ            LIMA             LIMA
# 2                2006            PERÚ            LIMA             LIMA
# 3                2005            PERÚ      LAMBAYEQUE         CHICLAYO
# 4                2004            PERÚ            LIMA             LIMA
# ...               ...             ...             ...              ...
# 15369            2006            PERÚ            LIMA             LIMA
# 15371            2005            PERÚ            LIMA             LIMA
# 15372            2005            PERÚ            LIMA             LIMA
# 15374            2005            PERÚ            LIMA             LIMA
# 15375            2007            PERÚ           JUNIN            JAUJA
#
#          NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  MODALIDAD  \
# 0            EL AGUSTINO  MASCULINO      13.382      SI  ORDINARIO
# 1            LA VICTORIA  MASCULINO       6.700      NO  ORDINARIO
# 2          PUENTE PIEDRA   FEMENINO       7.871      NO  ORDINARIO
# 3                 PATAPO   FEMENINO      12.536      NO  ORDINARIO
# 4            LA VICTORIA  MASCULINO      12.763      NO  ORDINARIO
# ...                  ...        ...         ...     ...        ...
# 15369               LIMA  MASCULINO       3.110      NO  ORDINARIO
# 15371                ATE  MASCULINO       3.205      NO  ORDINARIO
# 15372      PUENTE PIEDRA  MASCULINO       7.103      NO  ORDINARIO
# 15374  SANTIAGO DE SURCO  MASCULINO       5.592      NO  ORDINARIO
# 15375              MASMA  MASCULINO       6.667      NO  ORDINARIO
#
#        FECHA_CORTE
# 0         20250630
# 1         20250630
# 2         20250630
# 3         20250630
# 4         20250630
# ...            ...
# 15369     20250630
# 15371     20250630
# 15372     20250630
# 15374     20250630
# 15375     20250630
#
# [12317 rows x 23 columns]

# %%
df.query("ANIO_POSTULA > 2020")
# Out:
#                                                   IDHASH  \
# 0      FCE35CE48F105003AD25D7F42AED473CF15C9B0908246D...
# 1      95282C5990D24FDD3D89A3E9635709C0A25697799F65C5...
# 2      6B0941B84A667898E34B981F7CF89497F3897BA5B6BA24...
# 3      A1DC21280879F9C205F7C421B8152BE338225A3359D6BF...
# 4      EF4BC1BD9F868AAA10BAA5F7BEC08141B9C0D5F0BF3809...
# ...                                                  ...
# 15371  7A76871277BF7B50009F4B81FA156045AA677DC1F42AC5...
# 15372  B66283E6A854E54D4312BCEAFF77FA5BFEB1F0CD66D344...
# 15373  0E51C416C1698AA217D8F1F23014D89711142D0DCF2F4D...
# 15374  BE5CD944A10F2E7F44D7DA77527BD405513F729B205498...
# 15375  57E091594DAC88B02597F63AE7C6F8DCAC13CB74F57717...
#
#                            COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 0               VIRGEN DEL ROSARIO         LIMA         LIMA
# 1        MONSEÑOR MARCOS LIBARDONI         LIMA         LIMA
# 2                  3721 SANTA ROSA         LIMA         LIMA
# 3                        ARGENTINA         LIMA         LIMA
# 4                       SAN CARLOS         LIMA         LIMA
# ...                            ...          ...          ...
# 15371        1070 MELITON CARVAJAL         LIMA         LIMA
# 15372                    EL AMAUTA         LIMA         LIMA
# 15373              MOISES ZEBALLOS       ANCASH       SIHUAS
# 15374            6082 LOS PROCERES         LIMA         LIMA
# 15375  3045 JOSE CARLOS MARIATEGUI         LIMA         LIMA
#
#                COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 0                PACHACAMAC         PERÚ                 2023
# 1               LA VICTORIA         PERÚ                 2023
# 2                     ANCON         PERÚ                 2021
# 3                      LIMA         PERÚ                 2021
# 4                     COMAS         PERÚ                 2020
# ...                     ...          ...                  ...
# 15371                 LINCE         PERÚ                 2022
# 15372                 COMAS         PERÚ                 2021
# 15373             CHINGALPO         PERÚ                 2022
# 15374     SANTIAGO DE SURCO         PERÚ                 2022
# 15375  SAN MARTIN DE PORRES         PERÚ                 2023
#
#                   ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 0       INGENIERÍA ELECTRÓNICA          2024              2  ...
# 1          INGENIERÍA MECÁNICA          2024              2  ...
# 2         INGENIERÍA ECONÓMICA          2024              2  ...
# 3                 ARQUITECTURA          2024              2  ...
# 4                 ARQUITECTURA          2024              2  ...
# ...                        ...           ...            ...  ...
# 15371   INGENIERÍA ELECTRÓNICA          2025              1  ...
# 15372  INGENIERÍA PETROQUÍMICA          2025              1  ...
# 15373   INGENIERÍA ESTADÍSTICA          2025              1  ...
# 15374         INGENIERÍA CIVIL          2025              1  ...
# 15375   INGENIERÍA MECATRÓNICA          2025              1  ...
#
#       ANIO_NACIMIENTO NACIMIENTO_PAIS NACIMIENTO_DEPA  NACIMIENTO_PROV  \
# 0                2007            PERÚ            LIMA             LIMA
# 1                2006            PERÚ            LIMA             LIMA
# 2                2006            PERÚ            LIMA             LIMA
# 3                2005            PERÚ      LAMBAYEQUE         CHICLAYO
# 4                2004            PERÚ            LIMA             LIMA
# ...               ...             ...             ...              ...
# 15371            2005            PERÚ            LIMA             LIMA
# 15372            2005            PERÚ            LIMA             LIMA
# 15373            2006            PERÚ          ANCASH           SIHUAS
# 15374            2005            PERÚ            LIMA             LIMA
# 15375            2007            PERÚ           JUNIN            JAUJA
#
#          NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  MODALIDAD  \
# 0            EL AGUSTINO  MASCULINO      13.382      SI  ORDINARIO
# 1            LA VICTORIA  MASCULINO       6.700      NO  ORDINARIO
# 2          PUENTE PIEDRA   FEMENINO       7.871      NO  ORDINARIO
# 3                 PATAPO   FEMENINO      12.536      NO  ORDINARIO
# 4            LA VICTORIA  MASCULINO      12.763      NO  ORDINARIO
# ...                  ...        ...         ...     ...        ...
# 15371                ATE  MASCULINO       3.205      NO  ORDINARIO
# 15372      PUENTE PIEDRA  MASCULINO       7.103      NO  ORDINARIO
# 15373          CHINGALPO  MASCULINO       3.044      NO  ORDINARIO
# 15374  SANTIAGO DE SURCO  MASCULINO       5.592      NO  ORDINARIO
# 15375              MASMA  MASCULINO       6.667      NO  ORDINARIO
#
#        FECHA_CORTE
# 0         20250630
# 1         20250630
# 2         20250630
# 3         20250630
# 4         20250630
# ...            ...
# 15371     20250630
# 15372     20250630
# 15373     20250630
# 15374     20250630
# 15375     20250630
#
# [15376 rows x 23 columns]

# %% [markdown]
# En general, Pandas tiene una serie de métodos para filtrar información.
# Vamos viendo cuándo aplicar cada uno:
#
#
# | Método         | Ejemplo de uso                                                                                                        |
# |----------------|-----------------------------------------------------------------------------------------------------------------------|
# | `loc`          | `df.loc[(df['ANIO_POSTULA'] > 2020) & (df['ANIO_NACIMIENTO'] < 2000), 'ANIO_NACIMIENTO']`    |
# | `iloc`         | `df.iloc[0:5, 0:2]` Accede a las primeras 5 filas y primeras 2 columnas.                                                |
# | `query`        | `df.query('(ANIO_POSTULA > 2020) & (ANIO_NACIMIENTO < 2000)')`
# | `filter`       | `df.filter(items=['ANIO_NACIMIENTO', 'ANIO_POSTULA'])`                                          |
# | `where`        | `df.where((df['ANIO_POSTULA'] > 2020) & (df['ANIO_NACIMIENTO'] < 2000))` Preserva shape pero rellena con Nan     |
# | `mask`         | `df.mask((df['ANIO_POSTULA'] > 2020) & (df['ANIO_NACIMIENTO'] < 2000))` Cambia a NaN los valores donde 'ANIO_POSTULA' > 2020 y 'ANIO_NACIMIENTO' < 2000.                            |
# | `isin`         | `df[df['ANIO_NACIMIENTO'].isin([2000, 2001])]`

# %%
df.loc[
(df['ANIO_POSTULA'] > 2020
) & (
    df['ANIO_NACIMIENTO'] < 2000
), :]
# Out:
#                                                   IDHASH  \
# 45     E4FE91D00E255FE378DF1653810BC5746BE14967AB3AB4...
# 138    AC4FCF030FDAEACF07562BC85B29A6052ECF8DA8AE7389...
# 205    6ABEE75BB1F75C0F5866E89844DF14959C2482292532F4...
# 232    A686278E0C7F599104689C1A04B495504C91413452AA7A...
# 274    DE35B63846D571D1D35E22860A6CCF3E97D5221642D683...
# ...                                                  ...
# 15153  2B00C39051D012573F172427A424729488AD1613433403...
# 15182  DB24B7C0EB9D5E026CAAF99958BA19A558C3737E718740...
# 15227  2D2184D266CD0F0C08334B5DB1638CD690A92BCDB74261...
# 15242  307DFB49504D1C20FF67DB10F348B71DCE45BF8F17C755...
# 15302  D93C6B027B42162E84885F29F89D85938B1FDA56E17BED...
#
#                                   COLEGIO COLEGIO_DEPA COLEGIO_PROV  \
# 45                            JEAN PIAGET          ICA          ICA
# 138                           MIGUEL GRAU     APURIMAC      ABANCAY
# 205    LUCIE RYNNING DE ANTUNEZ DE MAYOLO         LIMA         LIMA
# 232                    5174 JUAN PABLO II         LIMA         LIMA
# 274             43006 MERCEDES INDACOCHEA        TACNA        TACNA
# ...                                   ...          ...          ...
# 15153             0168 AMISTAD PERU JAPON         LIMA         LIMA
# 15182                      LA FE DE MARIA         LIMA         LIMA
# 15227             5121 PEDRO PLANAS SILVA       CALLAO       CALLAO
# 15242                       SACO OLIVEROS         LIMA         LIMA
# 15302               SAN IGNACIO DE LOYOLA        CUSCO      CANCHIS
#
#                  COLEGIO_DIST COLEGIO_PAIS  COLEGIO_ANIO_EGRESO  \
# 45                LA TINGUINA         PERÚ                 2012
# 138                   ABANCAY         PERÚ                 2003
# 205                     RIMAC         PERÚ                 2016
# 232                CARABAYLLO         PERÚ                 2014
# 274                     TACNA         PERÚ                 2014
# ...                       ...          ...                  ...
# 15153  SAN JUAN DE LURIGANCHO         PERÚ                 2013
# 15182                   COMAS         PERÚ                 2015
# 15227              VENTANILLA         PERÚ                 2013
# 15242              LOS OLIVOS         PERÚ                 2015
# 15302                 SICUANI         PERÚ                 2016
#
#                     ESPECIALIDAD  ANIO_POSTULA  CICLO_POSTULA  ...  \
# 45              INGENIERÍA CIVIL          2024              2  ...
# 138                   MATEMÁTICA          2024              2  ...
# 205         INGENIERÍA AMBIENTAL          2024              2  ...
# 232            INGENIERÍA TEXTIL          2024              2  ...
# 274       INGENIERÍA ELECTRÓNICA          2025              1  ...
# ...                          ...           ...            ...  ...
# 15153    INGENIERIA AEROESPACIAL          2025              1  ...
# 15182     INGENIERÍA ESTADÍSTICA          2025              1  ...
# 15227  CIENCIA DE LA COMPUTACIÓN          2025              1  ...
# 15242                     FÍSICA          2025              1  ...
# 15302           INGENIERÍA NAVAL          2025              1  ...
#
#       ANIO_NACIMIENTO NACIMIENTO_PAIS NACIMIENTO_DEPA  NACIMIENTO_PROV  \
# 45               1995            PERÚ             ICA              ICA
# 138              1987            PERÚ        APURIMAC          ABANCAY
# 205              1999            PERÚ            LIMA             LIMA
# 232              1997            PERÚ            LIMA             LIMA
# 274              1997            PERÚ           TACNA            TACNA
# ...               ...             ...             ...              ...
# 15153            1997            PERÚ            LIMA             LIMA
# 15182            1999            PERÚ            LIMA             LIMA
# 15227            1998            PERÚ          CALLAO           CALLAO
# 15242            1999            PERÚ            LIMA             LIMA
# 15302            1999            PERÚ            PUNO           MELGAR
#
#               NACIMIENTO_DIST       SEXO CALIF_FINAL INGRESO  MODALIDAD  \
# 45                        ICA  MASCULINO      11.460      NO  ORDINARIO
# 138                   ABANCAY  MASCULINO       6.370      NO  ORDINARIO
# 205                      LIMA   FEMENINO      11.057      SI  ORDINARIO
# 232                      LIMA   FEMENINO       7.280      NO  ORDINARIO
# 274                     TACNA   FEMENINO       3.990      NO  ORDINARIO
# ...                       ...        ...         ...     ...        ...
# 15153  SAN JUAN DE LURIGANCHO  MASCULINO      12.738      SI  ORDINARIO
# 15182                    LIMA  MASCULINO       8.673      NO  ORDINARIO
# 15227              VENTANILLA  MASCULINO       0.000      NO  ORDINARIO
# 15242            PUEBLO LIBRE  MASCULINO      10.416      SI  ORDINARIO
# 15302              SANTA ROSA  MASCULINO       7.177      NO  ORDINARIO
#
#        FECHA_CORTE
# 45        20250630
# 138       20250630
# 205       20250630
# 232       20250630
# 274       20250630
# ...            ...
# 15153     20250630
# 15182     20250630
# 15227     20250630
# 15242     20250630
# 15302     20250630
#
# [176 rows x 23 columns]

# %% [markdown]
# ## Ejercicio:
# 1. Filtra el dataframe y quédate con quienes postularon a la 'ESPECIALIDAD' de INGENIERÍA MECATRÓNICA y cuyo lugar de nacimiento sea Callao.
# 2. Filtra el dataframe y quédate con los postulantes cuyo país de estudio no haya sido Perú.
# 3. Filtra el dataframe y quédate con los postulantes de nacieron en Cajamarca y sí ingresaron.
# 4. Filtra el dataframe y quédate con los postulantes que obtuvieron una calificación final mayor a 17 e ingresaron por modalidad ordinario.
